# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("instagram_data.csv")
data
# Out:
#              owner_id     owner_username    shortcode is_video  \
# 0            36063641  christendominique  C3_GS1ASeWI    False
# 1            36063641  christendominique  C38ivgNS3IX     True
# 2            36063641  christendominique  C35-Dd9SO1b     True
# 3            36063641  christendominique  C33TadDMisq     True
# 4            36063641  christendominique  C3s-Cm1yCba     True
# ...               ...                ...          ...      ...
# 11687       877755538           m_eye_nd  C35pT7pPs8e    False
# 11688       877755538           m_eye_nd  C34fjtCvi45    False
# 11689       877755538           m_eye_nd  C33nKF4vCQR    False
# 11690       877755538           m_eye_nd  C30xApcSaO5    False
# 11691  >>>>>>> origin                NaN          NaN      NaN
#
#                                                  caption comments  likes  \
# 0      I’m a brunch & Iced Coffee girlie☕️🍳 \n\nTop @...      268  16382
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of              owner_id     owner_username    shortcode is_video  \
# 0            36063641  christendominique  C3_GS1ASeWI    False
# 1            36063641  christendominique  C38ivgNS3IX     True
# 2            36063641  christendominique  C35-Dd9SO1b     True
# 3            36063641  christendominique  C33TadDMisq     True
# 4            36063641  christendominique  C3s-Cm1yCba     True
# ...               ...                ...          ...      ...
# 11687       877755538           m_eye_nd  C35pT7pPs8e    False
# 11688       877755538           m_eye_nd  C34fjtCvi45    False
# 11689       877755538           m_eye_nd  C33nKF4vCQR    False
# 11690       877755538           m_eye_nd  C30xApcSaO5    False
# 11691  >>>>>>> origin                NaN          NaN      NaN
#
#                                                  caption comments  likes  \
# 0      I’m a brunch & Iced Coffee girlie☕️🍳 \n\nTop @...      268  16382
# ...

# %%
print(data.isnull().sum())
# Out:
# owner_id              0
# owner_username        2
# shortcode             2
# is_video              2
# caption             161
# comments              2
# likes                 2
# created_at            3
# location           7169
# imageUrl              3
# multiple_images       3
# username           2115
# followers          2115
# following          2115
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
print(data.isnull().sum())
# Out:
# owner_id           0
# owner_username     0
# shortcode          0
# is_video           0
# caption            0
# comments           0
# likes              0
# created_at         0
# location           0
# imageUrl           0
# multiple_images    0
# username           0
# followers          0
# following          0
# dtype: int64

# %%
data['comments'] = pd.to_numeric(data['comments'], errors='coerce')

# %%
data.head()
# Out:
#     owner_id       owner_username    shortcode is_video  \
# 28  40506412  christinehmcconnell  CzJtDjegmdI    False
# 34  40506412  christinehmcconnell  Cqk5hb4AOGK    False
# 60  35843209          cintascotch  C1ABSmGMu1d     True
# 61  35843209          cintascotch  C372ffZOk1L    False
# 62  35843209          cintascotch  C3VT_Sos__Z     True
#
#                                               caption  comments  likes  \
# 28  Had an amazing time in #salem for Halloween th...       466  79000
# 34  Stopped by my favorite antique book store @lyr...       272  53254
# 60  Check out my 2023 reel! 🎥\n\nI invite you also...        25    297
# 61  🔵 🔵 🔵 Hold the dots and scroll right! 👉\n\n👁️ ...        73   1317
# 62  Happy Valentine’s Day! ❤️ Send this video to y...        22    680
#
#       created_at                                           location  \
# 28  1.698945e+09  {'id': '34537076', 'has_public_page': True, 'n...
# ...

# %%
print(data.describe())
# Out:
#             comments    created_at     followers     following
# count    3744.000000  3.744000e+03  3.744000e+03  3.744000e+03
# mean      343.200321  1.681608e+09  1.894394e+06  1.031337e+04
# std      3501.887682  4.969690e+07  6.845989e+06  1.198092e+05
# min         0.000000  1.450283e+09  1.000000e+00  0.000000e+00
# 25%        14.000000  1.685892e+09  1.971580e+05  4.200000e+02
# 50%        43.000000  1.705337e+09  4.990260e+05  7.850000e+02
# 75%       123.000000  1.708531e+09  1.117678e+06  1.296000e+03
# max    122771.000000  1.709526e+09  7.180750e+07  1.568394e+06

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_9092\480211352.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['likes'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='followers', y='likes', data=data, color='orange')
plt.title('Likes vs Followers')
plt.xlabel('Followers')
plt.ylabel('Likes')
plt.show()

# %%
data['likes'] = pd.to_numeric(data['likes'], errors='coerce')

# %%
data['is_video'] = data['is_video'].astype('category')

# %%
print(data.dtypes)
# Out:
# owner_id             object
# owner_username       object
# shortcode            object
# is_video           category
# caption              object
# comments              int64
# likes                 int64
# created_at          float64
# location             object
# imageUrl             object
# multiple_images      object
# username             object
# followers           float64
# following           float64
# dtype: object

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='is_video', y='likes', data=data, palette='Set2')
plt.title('Likes Distribution for Videos and Images')
plt.xlabel('Is Video')
plt.ylabel('Likes')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='owner_username', y='likes', data=data, estimator=sum, ci=None)
plt.title('Total Likes by Owner Username')
plt.xlabel('Owner Username')
plt.ylabel('Total Likes')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_9092\2187906342.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='owner_username', y='likes', data=data, estimator=sum, ci=None)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['comments'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Comments')
plt.xlabel('Number of Comments')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='followers', y='likes', data=data, color='orange')
plt.title('Likes vs Followers')
plt.xlabel('Followers')
plt.ylabel('Likes')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='is_video', data=data, palette='pastel')
plt.title('Count of Video vs. Image Posts')
plt.xlabel('Is Video')
plt.ylabel('Count')
plt.show()
